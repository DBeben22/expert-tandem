# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from helpers import plot_msSpectra

# %%
df = pd.read_csv("raw_data/spec_guest_20250418-013432-867.tsv", sep='\t', header=0)
df.head()
# Out:
#         m/z  intensity
# 0  101.1298    90.8070
# 1  102.1320    41.8321
# 2  110.0546  3916.4570
# 3  111.2084   233.2335
# 4  113.1376    79.2618

# %%
plot_msSpectra(df["m/z"],df["intensity"])
