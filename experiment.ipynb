# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from helpers import plot_msSpectra
import seaborn as sns

# %%
df = pd.read_csv("raw_data/spec_guest_20250420-050520-325.tsv", sep='\t', header=0)
df.head()
# Out:
#         m/z   intensity
# 0  110.0713  29422.7891
# 1  112.0868   4282.5659
# 2  113.0709   1195.4149
# 3  114.2358    821.0837
# 4  115.0865   9551.1641

# %%
plot_msSpectra(df["m/z"],df["intensity"])
# Out:
# 0.00455 0.006199999999992656 0.010749999999992656 0.0035
# 0.00455 0.0062999999999959755 0.010849999999995976 0.0035
# 0.00455 0.005799999999993588 0.010349999999993588 0.0035
# 0.00455 0.005800000000007799 0.0103500000000078 0.0035
# 0.00455 0.0062999999999959755 0.010849999999995976 0.0035
# 0.00455 0.005799999999993588 0.010349999999993588 0.0035
# 0.00455 0.005899999999996908 0.010449999999996908 0.0035
# 0.00455 0.005099999999998772 0.009649999999998772 0.0035

# %%
df.sort_values(by=["intensity"])["intensity"].plot(use_index=False,ylim=[0,10000])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 8))
sns.lineplot(x='index', y='intensity', data=df.sort_values(by=["intensity"]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(8, 8))
# ----> 2 sns.lineplot(x='index', y='intensity', data=df.sort_values(by=["intensity"]))
#       3 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# ...
