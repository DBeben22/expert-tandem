# %%
import pandas as pd

# %%
pd.read_csv("data/psm_a.tsv", sep="\t")
# Out:
#                               Spectrum     Spectrum File  \
# 0      2015-05-19_MRC5_a.05045.05045.4  interact.pep.xml
# 1      2015-05-19_MRC5_a.05137.05137.3  interact.pep.xml
# 2      2015-05-19_MRC5_a.05268.05268.3  interact.pep.xml
# 3      2015-05-19_MRC5_a.05273.05273.3  interact.pep.xml
# 4      2015-05-19_MRC5_a.05307.05307.3  interact.pep.xml
# ...                                ...               ...
# 12449  2015-05-19_MRC5_a.31234.31234.2  interact.pep.xml
# 12450  2015-05-19_MRC5_a.31254.31254.2  interact.pep.xml
# 12451  2015-05-19_MRC5_a.31266.31266.3  interact.pep.xml
# 12452  2015-05-19_MRC5_a.31268.31268.3  interact.pep.xml
# 12453  2015-05-19_MRC5_a.31269.31269.3  interact.pep.xml
#
#                        Peptide           Modified Peptide  \
# 0             VHGPGIQSGTTNKPNK                        NaN
# 1                 YHTVNGHNCEVR               YHTVNGHNCEVR
# 2               NQTAEKEEFEHQQK                        NaN
# ...
